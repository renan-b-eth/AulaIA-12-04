# %%
# !pip install --quiet matplotlib seaborn pandas scikit-learn

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Blood_samples_dataset_balanced_MODIFICADO.csv")
df.sample(5)
# Out:
#       Unnamed: 0   Glucose  Cholesterol  Hemoglobin  Platelets  \
# 966          966  0.149718     0.775277    0.855435   0.362927
# 1356        1356  0.398052     0.484758    0.556171   1.019925
# 842          842  0.385374     0.458952    0.903170   0.860483
# 986          986  0.806213     0.837078    0.576200   0.455820
# 171          171  0.379731     0.396114    0.775640   0.809283
#
#       White Blood Cells  Red Blood Cells  Hematocrit  Mean Corpuscular Volume  \
# 966            0.609378         0.385761    0.489251                 0.089665
# 1356           0.463967         0.845312    0.132958                 0.405963
# 842            1.039345         0.270160    0.752198                 0.333314
# 986            0.656912         1.136245    0.733311                 0.774595
# 171            0.698909         0.836213    0.562500                 0.223721
#
#       Mean Corpuscular Hemoglobin  ...     HbA1c  LDL Cholesterol  \
# ...

# %% [markdown]
# # Aprendizado de Maquina supervisionado para classificação ( possui vários paradigmas )
#
# alguem tem que dar informacão para ele poder classificar
# alguém vai supervisionar enquanto ela aprendre
# parece o teste de captcha do google
# classificar é separar os dados em categorias
# manipulamos (organizamos) dados para a maquina aprender
# colocamos os dados na maquina
# limpamos e separados os dados ( pre-classificado )
# a maquina aprende identificando padrões de forma autonoma com as superviçoes
#
# O machine learning (ML) é a tarefa de receber uma entrada $\mathbf{X}$ e a saida correta $\mathbf{y}$ (supervisão) e tem que construir uma função $f$ que mapeia $\mathbf{X} -> \rightarrow \mathbf{f}$. No futuro podemos usar $f$ para estimar a respostas de novas entradas $\mathbf{\hat{y}}$.

# %%
df = df.drop("Unnamed: 0", axis=1) # jogou a coluna fora
df.sample(5)
# Out:
#        Glucose  Cholesterol  Hemoglobin  Platelets  White Blood Cells  \
# 1696  0.222824     0.535933    0.345550   0.631852           0.665265
# 1029  0.090218     0.407417    0.217894   0.727925           0.119555
# 2194  0.274048     0.742877    0.566107   1.000106           0.448322
# 514   0.463814     0.509007    0.885762   0.482882           0.589836
# 1351  0.405370     0.336984    1.049366   0.686091           1.076371
#
#       Red Blood Cells  Hematocrit  Mean Corpuscular Volume  \
# 1696         0.221835    0.314290                 0.927270
# 1029         0.144749    0.899785                 1.201955
# 2194         0.973139    0.299209                 0.248262
# 514          1.078945    0.485639                 0.493178
# 1351         0.474151    0.785424                 0.469298
#
#       Mean Corpuscular Hemoglobin  Mean Corpuscular Hemoglobin Concentration  \
# 1696                     0.763206                                   0.381228
# ...

# %%
# shit in, shit out
# data literacy

for coluna in df.columns:
    print(coluna)
    sns.catplot(data=df, x="Disease", y=coluna, kind="bar", hue="Disease")
    plt.show()
# Out:
# Glucose
# Cholesterol
# Hemoglobin
# Platelets
# White Blood Cells
# Red Blood Cells
# Hematocrit
# Mean Corpuscular Volume
# Mean Corpuscular Hemoglobin
# Mean Corpuscular Hemoglobin Concentration
# Insulin
# BMI
# Systolic Blood Pressure
# Diastolic Blood Pressure
# Triglycerides
# HbA1c
# LDL Cholesterol
# HDL Cholesterol
# ALT
# AST
# Heart Rate
# Creatinine
# Troponin
# C-reactive Protein
# Disease
